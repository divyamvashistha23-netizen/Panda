# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamvashistha23-netizen/Panda/blob/main/panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#seires
import pandas as pd
data = [100.1, 103.5, 106.8]
series = pd.Series(data)
array = ["A", "B", "C"]
series2 = pd.Series(array, index = ['a', 'b', 'c'])
Data = [100, 103, 106]
series3 = pd.Series(Data, index = ['Room1', 'Room2', 'Room3'])
print(series)
print(series2)
print(series3)
# Out:
# 0    100.1
# 1    103.5
# 2    106.8
# dtype: float64
# a    A
# b    B
# c    C
# dtype: object
# Room1    100
# Room2    103
# Room3    106
# dtype: int64
